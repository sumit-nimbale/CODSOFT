# %%
# 02_preprocessing.ipynb

import pandas as pd

# Load raw data
df = pd.read_csv(r"D:\in\Task_2\Dataset\fraud_train.csv")

# Drop leakage / identifier columns
df.drop(columns=['cc_num', 'trans_num', 'Unnamed: 0'], inplace=True)

# Save cleaned dataset
df.to_csv("cleaned_data.csv", index=False)

print("✔ cleaned_data.csv saved")
# Out:
# ✔ cleaned_data.csv saved
